# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url1 = "/kaggle/input/power-consumption-in-india2019-2020/dataset_tk.csv"

# %%
url2 = '/kaggle/input/power-consumption-in-india2019-2020/long_data_.csv'

# %%
#Load the data
df=pd.read_csv(url1)
df

# %%
#To display first five records
df.head(5)

# %%
#To display last five records
df.tail(5)

# %%
#Load the data
df2=pd.read_csv(url2)
df2

# %%
#To display first five records
df2.head(5)

# %%
#To display last five records
df2.tail(5)

# %%
#To display all column names
df.columns

# %%
#To display all column names
df2.columns

# %%
#Giving a name 'Date' to unnamed column 
df.rename(columns={'Unnamed: 0':'Date'}, inplace=True)

# %%
df.head(5)

# %%
#To display states column
df2['States']

# %%
#To display unique values of states column
df2['States'].unique()

# %%
#To display number of unique values of states column
df2['States'].nunique()

# %%
#To display unique values of regions column
df2['Regions'].unique()

# %%
#To display number of unique values of regions column
df2['Regions'].nunique()

# %%
#To display unique values of latitude column
df2['latitude'].unique()

# %%
#To display number of unique values of latitude column
df2['latitude'].nunique()

# %%
#To display unique values of longitude column
df2['longitude'].unique()

# %%
#To display number of unique values of longitude column
df2['longitude'].nunique()

# %%
#To display unique values of Dates column
df2['Dates'].unique()

# %%
#To display number of unique values of Dates column
df2['Dates'].nunique()

# %%
#To display unique values of Date column from first dataset
df['Date'].unique()

# %%
#To display number of unique values of Date column from first dataset
df['Date'].nunique()

# %%
#To display unique values of Usage column
df2['Usage'].unique()

# %%
#To display number of unique values of Usage column
df2['Usage'].nunique()

# %% [markdown]
# # **Describing the data**

# %%
#describe() method returns description of the data in the DataFrame.
df.describe()

# %%
#describe() method returns description of the data in the DataFrame.
df2.describe()

# %%
#To display number of rows and columns
df.shape

# %%
#To display number of rows and columns
df2.shape

# %%
#To display number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values).
df.info()

# %%
#To display number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values).
df2.info()

# %%
#To return data type of each column. 
df.dtypes

# %%
#To return data type of each column. 
df2.dtypes

# %%
#To count the number of not empty values for each row
df.count()

# %%
#To count the number of not empty values for each row
df2.count()

# %% [markdown]
# # **Data Wrangling**

# %%
#To display the number of empty values (NaN,NAN,na) in each column
df.isna()

# %%
#To display the number of empty values (NaN,NAN,na) in each column
df2.isna()

# %%
#Count the number of empty values (NaN,NAN,na) in each column
df.isna().sum()

# %%
#Count the number of empty values (NaN,NAN,na) in each column
df2.isna().sum()

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
#Visualization of data using matplotlib.pyplot library
import matplotlib.pyplot as plt
plt.hist(df2['Regions'])
plt.show()

# %%
df2.groupby('Regions').size()

# %%
import matplotlib.pyplot as plt
x=df2['Regions']
y=df2['longitude']
plt.bar(x,y)
plt.title("Barchart of Regions and Longitude")
plt.xlabel("Regions")
plt.ylabel("Longitude")
plt.show()

# %%
import matplotlib.pyplot as plt
x=df2['Regions']
y=df2['latitude']
plt.bar(x,y)
plt.title("Barchart of Regions and Latitude")
plt.xlabel("Regions")
plt.ylabel("Latitude")
plt.show()

# %%
import matplotlib.pyplot as plt
x=df2['Regions']
y=df2['Usage']
plt.bar(x,y)
plt.title("Barchart of Regions and Usage")
plt.xlabel("Regions")
plt.ylabel("Usage")
plt.show()

# %%
#Visualization of data using seaborn library
import seaborn as sns
#Visualizing Regions using countplot
#A count plot is helpful when dealing with categorical values. It is used to plot the frequency of the different categories.
sns.countplot(x='Regions',data=df2)

# %%
#relation of Regions with latitude
sns.boxplot(x=df2['Regions'],y=df2['latitude'])

# %%
#relation of Regions with longitude
sns.boxplot(x=df2['Regions'],y=df2['longitude'])

# %%
#relation of Regions with Usage
sns.boxplot(x=df2['Regions'],y=df2['Usage'])

# %%
#ENCODING
from sklearn.preprocessing import OneHotEncoder
onehot_encoder=OneHotEncoder()
df2['States']=onehot_encoder.fit_transform(df2[['States']]).toarray()
df2['States'].values

# %%
#ENCODING
from sklearn.preprocessing import OneHotEncoder
onehot_encoder=OneHotEncoder()
df2['Regions']=onehot_encoder.fit_transform(df2[['Regions']]).toarray()
df2['Regions'].values

# %% [markdown]
# # **Correlation Analysis**

# %%
#Finding the correlation 
#corr() function tells us how one column can influence the other
data1=df2.iloc[:,[0,1,2,3,5]].corr()
data1

# %%
#Visualize the correlation of above data using heatmap
sns.heatmap(data1,annot=True,fmt='.0%')

# %%
#Finding the correlation 
#corr() function tells us how one column can influence the other
data2=df.iloc[:,1:11].corr()
data2

# %%
#Visualize the correlation of above data using heatmap
sns.heatmap(data2,annot=True,fmt='.0%')

# %%
#Finding the correlation 
#corr() function tells us how one column can influence the other
data3=df.iloc[:,11:21].corr()
data3

# %%
#Visualize the correlation of above data using heatmap
sns.heatmap(data3,annot=True,fmt='.0%')

# %%
#Finding the correlation 
#corr() function tells us how one column can influence the other
data4=df.iloc[:,21:].corr()
data4

# %%
#Visualize the correlation of above data using heatmap
sns.heatmap(data4,annot=True,fmt='.0%')

# %% [markdown]
# # **Customer Segmentation**

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

segmentation_data = df2[['latitude', 'Usage']]
scaler = StandardScaler()
segmentation_data_scaled = scaler.fit_transform(segmentation_data)

# Determine the optimal number of clusters using the Elbow Method
wcss = []  # Within-Cluster-Sum-of-Squares
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(segmentation_data_scaled)
    wcss.append(kmeans.inertia_)

# Plot the Elbow Method graph
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')  # Within-Cluster-Sum-of-Squares
plt.show()

# %%
# Choose the optimal k and fit the KMeans model
optimal_k = 3  # Determine from the Elbow Method
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
df2['Cluster'] = kmeans.fit_predict(segmentation_data_scaled)

# Visualize the clusters
plt.scatter(df2['latitude'], df2['Usage'], c=df2['Cluster'], cmap='viridis')
plt.title('Customer Segmentation')
plt.xlabel('Latitude')
plt.ylabel('Usage')
plt.show()

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

segmentation_data = df2[['longitude', 'Usage']]
scaler = StandardScaler()
segmentation_data_scaled = scaler.fit_transform(segmentation_data)

# Determine the optimal number of clusters using the Elbow Method
wcss = []  # Within-Cluster-Sum-of-Squares
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(segmentation_data_scaled)
    wcss.append(kmeans.inertia_)

# Plot the Elbow Method graph
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')  # Within-Cluster-Sum-of-Squares
plt.show()

# %%
# Choose the optimal k and fit the KMeans model
optimal_k = 3  # Determine from the Elbow Method
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
df2['Cluster'] = kmeans.fit_predict(segmentation_data_scaled)

# Visualize the clusters
plt.scatter(df2['longitude'], df2['Usage'], c=df2['Cluster'], cmap='viridis')
plt.title('Customer Segmentation')
plt.xlabel('Longitude')
plt.ylabel('Usage')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='longitude', y='Usage', data=df2)
plt.title('Line plot of Longitude and Usage')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='latitude', y='Usage', data=df2)
plt.title('Line plot of Latitude and usage')
plt.show()

# %%
import plotly.express as px

# %%
fig = px.line(df2, x='Dates', y='Usage')
fig.show()

# %%
df.drop(df.columns[2:], axis = 1, inplace = True)

# %%
df

# %%
plt.style.use("dark_background")
plt.rcParams.update({'figure.figsize': (40, 10), 'font.size': 24})

# %%
plt.plot(df["Date"], df["Punjab"])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

seasonal_decompose(df["Punjab"], model='additive', period = 30).plot().show()
m = seasonal_decompose(df["Punjab"], model='multiplicative', period = 30)
m.plot().show()

# %%
from statsmodels.tsa.stattools import adfuller, kpss

def adf_test(result):
    print('ADF Statistic: %f' % result[0])
    print('p-value: %.18f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

    print ("\n stationary \n" if result[1] < 0.05 else "\n Non stationary \n")

def kpss_test(result):    
    print('kpss Statistic: %f' % result[0])
    print('p-value: %.18f' % result[1])
    print('Critical Values:')
#     for key, value in result[4].items():
#         print('\t%s: %.3f' % (key, value))

    print ("\n stationary \n" if result[1] < 0.05 else "\n Non stationary \n")

adf_test(adfuller(df["Punjab"]))
kpss_test(kpss(df["Punjab"]))

# %%
(df["Punjab"] / m.trend).plot()

# %%
(df["Punjab"]/ m.seasonal).plot()

# %%
pd.plotting.autocorrelation_plot(df["Punjab"])

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

print (plot_acf(df["Punjab"], lags = 180))

# %%
print (plot_pacf(df["Punjab"], lags = 90))
